# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.manifold
import sklearn.datasets
import glob
import sklearn.cluster
import pandas as pd

# %%
files=glob.glob("./Stocks/*.txt")
print(np.shape(files))
print(files[:20])
# Out:
# (7194,)
# ['./Stocks/ardc.us.txt', './Stocks/epix.us.txt', './Stocks/eab.us.txt', './Stocks/batra.us.txt', './Stocks/inbk.us.txt', './Stocks/bgx.us.txt', './Stocks/strt.us.txt', './Stocks/manh.us.txt', './Stocks/atus.us.txt', './Stocks/icbk.us.txt', './Stocks/ftnt.us.txt', './Stocks/nhld.us.txt', './Stocks/dfs.us.txt', './Stocks/scvl.us.txt', './Stocks/ing.us.txt', './Stocks/hope.us.txt', './Stocks/jpt.us.txt', './Stocks/ocfc.us.txt', './Stocks/gsk.us.txt', './Stocks/apog.us.txt']

# %%
# Analizo todas los  x="high" y="nombre del archivo"

# %%
#Datos excluidos
for f in files[:n_max]:
    data = pd.read_csv("{}".format(f),delimiter=",")
    if[len(data["Date"])<50]:
        print(f)
# Out:
# ./Stocks/ardc.us.txt
# ./Stocks/epix.us.txt
# ./Stocks/eab.us.txt
# ./Stocks/batra.us.txt
# ./Stocks/inbk.us.txt
# ./Stocks/bgx.us.txt
# ./Stocks/strt.us.txt
# ./Stocks/manh.us.txt
# ./Stocks/atus.us.txt
# ./Stocks/icbk.us.txt
# ./Stocks/ftnt.us.txt
# ./Stocks/nhld.us.txt
# ./Stocks/dfs.us.txt
# ./Stocks/scvl.us.txt
# ./Stocks/ing.us.txt
# ./Stocks/hope.us.txt
# ./Stocks/jpt.us.txt
# ./Stocks/ocfc.us.txt
# ./Stocks/gsk.us.txt
# ./Stocks/apog.us.txt
# ./Stocks/mlvf.us.txt
# ./Stocks/ktn.us.txt
# ./Stocks/stot.us.txt
# ./Stocks/rcky.us.txt
# ./Stocks/ldl.us.txt
# ./Stocks/dlx.us.txt
# ./Stocks/rtix.us.txt
# ./Stocks/sb.us.txt
# ./Stocks/hyb.us.txt
# ./Stocks/ckh.us.txt
# ./Stocks/gne.us.txt
# ./Stocks/scacw.us.txt
# ./Stocks/spb.us.txt
# ./Stocks/eye.us.txt
# ./Stocks/oilu.us.txt
# ./Stocks/iii.us.txt
# ./Stocks/fomx.us.txt
# ./Stocks/yume.us.txt
# ./Stocks/tpre.us.txt
# ./Stocks/fran.us.txt
# ./Stocks/krma.us.txt
# ./Stocks/ale.us.txt
# ./Stocks/bxp_b.us.txt
# ./Stocks/mlp.us.txt
# ./Stocks/amed.us.txt
# ./Stocks/pmbc.us.txt
# ./Stocks/ship.us.txt
# ./Stocks/ergf.us.txt
# ./Stocks/sonc.us.txt
# ./Stocks/cw.us.txt
# ./Stocks/ubs.us.txt
# ./Stocks/orrf.us.txt
# ./Stocks/race.us.txt
# ./Stocks/evgbc.us.txt
# ./Stocks/hsea.us.txt
# ./Stocks/dcf.us.txt
# ./Stocks/nfbk.us.txt
# ./Stocks/agfs.us.txt
# ./Stocks/clvs.us.txt
# ./Stocks/uri.us.txt
# ./Stocks/mkl.us.txt
# ./Stocks/mnr.us.txt
# ./Stocks/swin.us.txt
# ./Stocks/lvus.us.txt
# ./Stocks/cil.us.txt
# ./Stocks/aoi.us.txt
# ./Stocks/vsec.us.txt
# ./Stocks/bokfl.us.txt
# ./Stocks/pre_i.us.txt
# ./Stocks/sti_a.us.txt
# ./Stocks/plbc.us.txt
# ./Stocks/slct.us.txt
# ./Stocks/eqrr.us.txt
# ./Stocks/capr.us.txt
# ./Stocks/mdly.us.txt
# ./Stocks/bym.us.txt
# ./Stocks/qtwo.us.txt
# ./Stocks/sq.us.txt
# ./Stocks/cnacw.us.txt
# ./Stocks/faro.us.txt
# ./Stocks/gds.us.txt
# ./Stocks/jw-b.us.txt
# ./Stocks/es.us.txt
# ./Stocks/cstr.us.txt
# ./Stocks/hdaw.us.txt
# ./Stocks/ivlu.us.txt
# ./Stocks/sphs.us.txt
# ./Stocks/grfs.us.txt
# ./Stocks/cunb.us.txt
# ./Stocks/ppc.us.txt
# ./Stocks/ntrs.us.txt
# ./Stocks/jp.us.txt
# ./Stocks/bsjo.us.txt
# ./Stocks/urbn.us.txt
# ./Stocks/atri.us.txt
# ./Stocks/vsat.us.txt
# ./Stocks/brgl.us.txt
# ./Stocks/hpq.us.txt
# ./Stocks/agnc.us.txt
# ./Stocks/emi.us.txt
# ./Stocks/save.us.txt
# ./Stocks/trno.us.txt
# ./Stocks/vbtx.us.txt
# ./Stocks/aval.us.txt
# ./Stocks/cim_b.us.txt
# ./Stocks/fonr.us.txt
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-85-4e2ba3dd999e> in <module>
#       1 #Datos excluidos
#       2 for f in files[:n_max]:
# ----> 3     data = pd.read_csv("{}".format(f),delimiter=",")
#       4     if[len(data["Date"])<50]:
#       5         print(f)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
#n_max=20#number of files taken
n_data=50# last days taken
n_max=len(files)
X=[]
Y=np.arange(n_max)
for f in files[:n_max]:
    print(f)
    data = pd.read_csv("{}".format(f),delimiter=",")
    label=data.keys()
    if[len(data[label[0]])>49]:
        X=np.append(X,data[label[2]][-n_data:])#toma todos los datos con high
#        Y=np.append(Y,data[label[4]][-n_data:])#toma todos los datos con high
X=X.reshape(n_max,n_data)
#Y=Y.reshape(n_max,n_data)
#print(20*3201)
print(np.shape(X))
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-86-385568d081a1> in <module>
#       6 for f in files[:n_max]:
#       7     #print(f)
# ----> 8     data = pd.read_csv("{}".format(f),delimiter=",")
#       9     label=data.keys()
#      10     if[len(data[label[0]])>49]:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
tsne = sklearn.manifold.TSNE(perplexity=20)
tsne.fit(X)
embedding = tsne.embedding_
np.shape(embedding)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-74506df21ae7> in <module>
#       1 tsne = sklearn.manifold.TSNE(perplexity=20)
# ----> 2 tsne.fit(X)
#       3 embedding = tsne.embedding_
#       4 np.shape(embedding)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/manifold/t_sne.py in fit(self, X, y)
#     910         y : Ignored
#     911         """
# --> 912         self.fit_transform(X)
#     913         return self
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     893             Embedding of the training data in low-dimensional space.
#     894         """
# --> 895         embedding = self._fit(X)
#     896         self.embedding_ = embedding
#     897         return self.embedding_
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     698         if self.method == 'barnes_hut':
#     699             X = check_array(X, ensure_min_samples=2,
# --> 700                             dtype=[np.float32, np.float64])
#     701         else:
#     702             X = check_array(X, accept_sparse=['csr', 'csc', 'coo'],
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     519                     "Reshape your data either using array.reshape(-1, 1) if "
#     520                     "your data has a single feature or array.reshape(1, -1) "
# --> 521                     "if it contains a single sample.".format(array))
#     522
#     523         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[16.249 16.239 16.189 ... 55.2   54.525 55.5  ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
labels=data.keys()
print(labels)
print(np.shape(data))
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')
# (3201, 7)

# %%
plt.scatter(embedding[:,0], embedding[:,1], c=Y, cmap='Paired', s=2.0)
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(Y)
